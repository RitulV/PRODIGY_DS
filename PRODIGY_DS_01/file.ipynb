# %%
# importing all required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# reading data into a pandas dataframe

df = pd.read_csv("API_SP.csv", header=2)

# %%
df.shape
# Out:
# (266, 67)

# %%
df.drop(labels=['Country Code', 'Indicator Name','Indicator Code'], axis=1, inplace=True)
df.head()
# Out:
#                   Country Name         1960         1961         1962  \
# 0                        Aruba      54608.0      55811.0      56682.0
# 1  Africa Eastern and Southern  130692579.0  134169237.0  137835590.0
# 2                  Afghanistan    8622466.0    8790140.0    8969047.0
# 3   Africa Western and Central   97256290.0   99314028.0  101445032.0
# 4                       Angola    5357195.0    5441333.0    5521400.0
#
#           1963         1964         1965         1966         1967  \
# 0      57475.0      58178.0      58782.0      59291.0      59522.0
# 1  141630546.0  145605995.0  149742351.0  153955516.0  158313235.0
# 2    9157465.0    9355514.0    9565147.0    9783147.0   10010030.0
# 3  103667517.0  105959979.0  108336203.0  110798486.0  113319950.0
# 4    5599827.0    5673199.0    5736582.0    5787044.0    5827503.0
#
#           1968  ...         2013         2014         2015         2016  \
# ...

# %%
country_names = df['Country Name']
country_names
# Out:
# 0                            Aruba
# 1      Africa Eastern and Southern
# 2                      Afghanistan
# 3       Africa Western and Central
# 4                           Angola
#                   ...
# 261                         Kosovo
# 262                    Yemen, Rep.
# 263                   South Africa
# 264                         Zambia
# 265                       Zimbabwe
# Name: Country Name, Length: 266, dtype: object

# %%
df_dropped = df.drop(labels=['Country Name'], axis=1)
df_dropped
# Out:
#             1960         1961         1962         1963         1964  \
# 0        54608.0      55811.0      56682.0      57475.0      58178.0
# 1    130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2      8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3     97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4      5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
# ..           ...          ...          ...          ...          ...
# 261     947000.0     966000.0     994000.0    1022000.0    1050000.0
# 262    5542459.0    5646668.0    5753386.0    5860197.0    5973803.0
# 263   16520441.0   16989464.0   17503133.0   18042215.0   18603097.0
# 264    3119430.0    3219451.0    3323427.0    3431381.0    3542764.0
# 265    3806310.0    3925952.0    4049778.0    4177931.0    4310332.0
#
#             1965         1966         1967         1968         1969  ...  \
# ...

# %%
df_total = df_dropped.sum(axis=1)
print(type(df_total))
df_total = df_total.tolist()
print(type(df_total))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'list'>

# %%
country_names = country_names.to_frame()
country_names.insert(loc=1, column='Total', value=df_total)
country_total = country_names
country_total
# Out:
#                     Country Name         Total
# 0                          Aruba  4.879739e+06
# 1    Africa Eastern and Southern  2.217097e+10
# 2                    Afghanistan  1.159837e+09
# 3     Africa Western and Central  1.510465e+10
# 4                         Angola  9.354095e+08
# ..                           ...           ...
# 261                       Kosovo  1.008997e+08
# 262                  Yemen, Rep.  9.974945e+08
# 263                 South Africa  2.432151e+09
# 264                       Zambia  5.704948e+08
# 265                     Zimbabwe  6.090421e+08
#
# [266 rows x 2 columns]

# %%
# Barplot

first_10_countries = country_total.head(20)

# Create the Barplot
plt.figure(figsize=(10, 8))  # Adjust figure size for better visualization
sns.barplot(x='Country Name', y='Total', data=first_10_countries)
plt.xlabel('Country')
plt.ylabel('Total Population')
plt.title('Barplot of Total Population for the First 10 Countries')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.tight_layout()

plt.show()

# %%
# Histogram

df.set_index('Country Name', inplace=True)

years = list(map(str, range(1960, 1971)))

df_t = df.loc[['Afghanistan', 'India', 'South Africa'], years]

#x-tick values
count, bin_edges = np.histogram(df_t, 10)

df_t.plot(kind='hist',
          figsize=(10, 8), 
          bins=10,
          xticks=bin_edges,
          color=['coral', 'darkslateblue', 'mediumseagreen'],
          stacked=True,
         )
plt.title('Histogram of Population from Afghanistan, India, and South Africa from 1960 - 1970')
plt.ylabel('Years')
plt.xlabel('Population')

plt.show()
